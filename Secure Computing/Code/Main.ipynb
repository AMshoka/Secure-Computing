# %%
# %load_ext sql
# %sql sqlite:///mydb.db

# %%
# %%sql
# SELECT *
# FROM raw_data
# Out:
#  * sqlite:///mydb.db
# Done.
# [(5, 55, 12, 14), (15, 150, 21, 18), (25, 250, 25, 19), (35, 350, 30, 20)]

# %%
# %%sql
# Select *
# from encrypt_data1
# Out:
#  * sqlite:///mydb.db
# Done.
# [('gAAAAABesLSYpDoDwno9Re54MStZLjy6sJo21qcKRJTPoFZcyDsNARR255oZOY_8hLX9xSfn2gUHjEWb_GFXByWEHGzdAZyZlw==', 1, 1, 2, 3),
#  ('gAAAAABesLVlHD2WTlmz0UKs7TGJ2UMDDVla6ShCz7xaNse42YVPFKhq96Jau0psKrDvxTsN3dKYgVyGAubCzIzz24XSwyS77RX35TX6RMRUtA4zELme8lU=', 2, 2, 3, 4),
#  ('gAAAAABesLV6Zia5TvmWG4CbT-F79ZHcRkdrZBTCMbVabGz1DGHlaQ0IgOYYpn4gzRTAjjs-s-zCjVxwTt7Noam4pXpNHdrSkf5gt6lQCbOYjPu8N8A_oBg=', 3, 2, 3, 4),
#  ('gAAAAABesLWSMCENc53mNANHX8zjAvka94yMwlnL829T6-hPjcUQYxLi7VsPZu2eHA70Ei7dn-345BPEv7GX2WJnv1aD2n0rJhHdMqh6pFS9tmMHz2Apzw8=', 4, 3, 4, 4)]

# %%
from cryptography.fernet import Fernet
def write_key():
    """
    Generates a key and save it into a file
    """
    key = Fernet.generate_key()
    with open("key.key", "wb") as key_file:
        key_file.write(key)
def load_key():
    """
    Loads the key from the current directory named `key.key`
    """
    return open("key.key", "rb").read()

# %%
import sqlite3
from prettytable import PrettyTable
conn=sqlite3.connect('mydb.db')
c=conn.cursor()
key = load_key()
f = Fernet(key)
flag = True
start = """
*********************
welcom to SarvSearch
# menu 
1 : search StudentID
2 : search NationalID
3 : search Age
4 : search Grade
*********************"""
print(start)
while flag :
    inp = int(input("please Select a number from 1 to 4 :"))
    if inp == 1:
        in2 = int(input("enter StudentID: "))
        if in2 > 0 and in2 <= 9 :
            query_sid = f'Select encrypt from encrypt_data1 Where Isid = {1}'
            y=c.execute(query_sid)
            l=[]
            for row in y:
                l.append(str(row))
              
            for i in l:
                en = str.encode(i)[2:len(str.encode(i))-3]
                decrypted_encrypted = f.decrypt(en)
                res = tuple(map(int, decrypted_encrypted.decode()[1:len(decrypted_encrypted.decode())-1].split(', '))) 
                if res[0]==in2:
                    print("your Query Result is:")
                    
                    t = PrettyTable(['sid' ,'nid' , 'age', 'grade'])
                    t.add_row([res[0],res[1], res[2],res[3]])
                    print(t)
                    print("\n")
                    print("More details:\n")
                    print("===>>>Recovered records from BigData:")
                    print(l)
                    print()
                    print("===>>>encrypted data is:"+str(en))
                    print()
                    print("*****The generated key is==>>> b'CiWj2kb9hg3SXUBVYXrfDcbXe28Iy1E5a5SFHyCPq5M='****** \n")
        
                
               
            flag = False
        elif in2 >= 10 and in2 <= 19:
            query_sid = f'Select encrypt from encrypt_data1 Where Isid = {2}'
            y=c.execute(query_sid)
            l=[]
            for row in y:
                l.append(str(row))
            for i in l:
                en = str.encode(i)[2:len(str.encode(i))-3]
                decrypted_encrypted = f.decrypt(en)
                res = tuple(map(int, decrypted_encrypted.decode()[1:len(decrypted_encrypted.decode())-1].split(', '))) 
                if res[0]==in2:
                    print("your Query Result is:")
                    
                    t = PrettyTable(['sid' ,'nid' , 'age', 'grade'])
                    t.add_row([res[0],res[1], res[2],res[3]])
                    print(t)
                    print("\n")
                    print("More details:\n")
                    print("===>>>Recovered records from BigData:")
                    print(l)
                    print()
                    print("===>>>encrypted data is:"+str(en))
                    print()
                    print("*****The generated key is==>>> b'CiWj2kb9hg3SXUBVYXrfDcbXe28Iy1E5a5SFHyCPq5M='****** \n")
          
              
          
            flag = False        
        elif in2 >= 20 and in2 <= 29:
            query_sid = f'Select encrypt from encrypt_data1 Where Isid = {3}'
            y=c.execute(query_sid)
            l=[]
            for row in y:
                l.append(str(row))
              
            for i in l:
                en = str.encode(i)[2:len(str.encode(i))-3]
                decrypted_encrypted = f.decrypt(en)
                res = tuple(map(int, decrypted_encrypted.decode()[1:len(decrypted_encrypted.decode())-1].split(', '))) 
                if res[0]==in2:
                    print("your Query Result is:")
                    
                    t = PrettyTable(['sid' ,'nid' , 'age', 'grade'])
                    t.add_row([res[0],res[1], res[2],res[3]])
                    print(t)
                    print("\n")
                    print("More details:\n")
                    print("===>>>Recovered records from BigData:")
                    print(l)
                    print()
                    print("===>>>encrypted data is:"+str(en))
                    print()
                    print("*****The generated key is==>>> b'CiWj2kb9hg3SXUBVYXrfDcbXe28Iy1E5a5SFHyCPq5M='****** \n")
        
            flag = False       
        elif in2 >= 30 and in2 <= 39:
            query_sid = f'Select encrypt from encrypt_data1 Where Isid = {4}'
            y=c.execute(query_sid)
            l=[]
            for row in y:
                l.append(str(row))
              
            for i in l:
                en = str.encode(i)[2:len(str.encode(i))-3]
                decrypted_encrypted = f.decrypt(en)
                res = tuple(map(int, decrypted_encrypted.decode()[1:len(decrypted_encrypted.decode())-1].split(', '))) 
                if res[0]==in2:
                    print("your Query Result is:")
                    
                    t = PrettyTable(['sid' ,'nid' , 'age', 'grade'])
                    t.add_row([res[0],res[1], res[2],res[3]])
                    print(t)
                    print("\n")
                    print("More details:\n")
                    print("===>>>Recovered records from BigData:")
                    print(l)
                    print()
                    print("===>>>encrypted data is:"+str(en))
                    print()
                    print("*****The generated key is==>>> b'CiWj2kb9hg3SXUBVYXrfDcbXe28Iy1E5a5SFHyCPq5M='****** \n")
        
            flag = False        
        else :
            print("contact IGZ 09086493523")
   ##########################################################################################         
        
    elif inp == 2:
        in2 = int(input("enter Inid: "))
        if in2 > 0 and in2 <= 99 :
            query_sid = f'Select encrypt from encrypt_data1 Where Inid = {1}'
            y=c.execute(query_sid)
            l=[]
            for row in y:
                l.append(str(row))
              
            for i in l:
                en = str.encode(i)[2:len(str.encode(i))-3]
                decrypted_encrypted = f.decrypt(en)
                res = tuple(map(int, decrypted_encrypted.decode()[1:len(decrypted_encrypted.decode())-1].split(', '))) 
                if res[1]==in2:
                    print("your Query Result is:")
                    
                    t = PrettyTable(['sid' ,'nid' , 'age', 'grade'])
                    t.add_row([res[0],res[1], res[2],res[3]])
                    print(t)
                    print("\n")
                    print("More details:\n")
                    print("===>>>Recovered records from BigData:")
                    print(l)
                    print()
                    print("===>>>encrypted data is:"+str(en))
                    print()
                    print("*****The generated key is==>>> b'CiWj2kb9hg3SXUBVYXrfDcbXe28Iy1E5a5SFHyCPq5M='****** \n")
        
                
               
            flag = False
        elif in2 >= 100 and in2 <= 299:
            query_sid = f'Select encrypt from encrypt_data1 Where Inid = {2}'
            y=c.execute(query_sid)
            l=[]
            for row in y:
                l.append(str(row))
                
            
                
            for i in l:
                en = str.encode(i)[2:len(str.encode(i))-3]
                decrypted_encrypted = f.decrypt(en)
                res = tuple(map(int, decrypted_encrypted.decode()[1:len(decrypted_encrypted.decode())-1].split(', '))) 
                if res[1]==in2:
                    print("your Query Result is:")
                    
                    t = PrettyTable(['sid' ,'nid' , 'age', 'grade'])
                    t.add_row([res[0],res[1], res[2],res[3]])
                    print(t)
                    print("\n")
                    print("More details:\n")
                    print("===>>>Recovered records from BigData:")
                    print(l)
                    print()
                    print("===>>>encrypted data is:"+str(en))
                    print()
                    print("*****The generated key is==>>> b'CiWj2kb9hg3SXUBVYXrfDcbXe28Iy1E5a5SFHyCPq5M='****** \n")
          
              
          
            flag = False        
        elif in2 >= 300:
            query_sid = f'Select encrypt from encrypt_data1 Where Inid = {3}'
            y=c.execute(query_sid)
            l=[]
            for row in y:
                l.append(str(row))
              
            for i in l:
                en = str.encode(i)[2:len(str.encode(i))-3]
                decrypted_encrypted = f.decrypt(en)
                res = tuple(map(int, decrypted_encrypted.decode()[1:len(decrypted_encrypted.decode())-1].split(', '))) 
                if res[1]==in2:
                    print("your Query Result is:")
                    
                    t = PrettyTable(['sid' ,'nid' , 'age', 'grade'])
                    t.add_row([res[0],res[1], res[2],res[3]])
                    print(t)
                    print("\n")
                    print("More details:\n")
                    print("===>>>Recovered records from BigData:")
                    print(l)
                    print()
                    print("===>>>encrypted data is:"+str(en))
                    print()
                    print("*****The generated key is==>>> b'CiWj2kb9hg3SXUBVYXrfDcbXe28Iy1E5a5SFHyCPq5M='****** \n")
        
                
       
            flag = False        
        else :
            print("contact IGZ 09086493523")
            
 ########################################################################           
    elif inp == 3:
        in2 = int(input("enter Iage: "))
        if in2 > 0 and in2 <= 9 :
            query_sid = f'Select encrypt from encrypt_data1 Where Iage = {1}'
            y=c.execute(query_sid)
            l=[]
            for row in y:
                l.append(str(row))
              
            for i in l:
                en = str.encode(i)[2:len(str.encode(i))-3]
                decrypted_encrypted = f.decrypt(en)
                res = tuple(map(int, decrypted_encrypted.decode()[1:len(decrypted_encrypted.decode())-1].split(', '))) 
                if res[2]==in2:
                    print("your Query Result is:")
                    
                    t = PrettyTable(['sid' ,'nid' , 'age', 'grade'])
                    t.add_row([res[0],res[1], res[2],res[3]])
                    print(t)
                    print("\n")
                    print("More details:\n")
                    print("===>>>Recovered records from BigData:")
                    print(l)
                    print()
                    print("===>>>encrypted data is:"+str(en))
                    print()
                    print("*****The generated key is==>>> b'CiWj2kb9hg3SXUBVYXrfDcbXe28Iy1E5a5SFHyCPq5M='****** \n")
        
                
               
            flag = False
        elif in2 >= 10 and in2 <= 19:
            query_sid = f'Select encrypt from encrypt_data1 Where Iage = {2}'
            y=c.execute(query_sid)
            l=[]
            for row in y:
                l.append(str(row))
                
            for i in l:
                en = str.encode(i)[2:len(str.encode(i))-3]
                decrypted_encrypted = f.decrypt(en)
                res = tuple(map(int, decrypted_encrypted.decode()[1:len(decrypted_encrypted.decode())-1].split(', '))) 
                if res[2]==in2:
                    print("your Query Result is:")
                    
                    t = PrettyTable(['sid' ,'nid' , 'age', 'grade'])
                    t.add_row([res[0],res[1], res[2],res[3]])
                    print(t)
                    print("\n")
                    print("More details:\n")
                    print("===>>>Recovered records from BigData:")
                    print(l)
                    print()
                    print("===>>>encrypted data is:"+str(en))
                    print()
                    print("*****The generated key is==>>> b'CiWj2kb9hg3SXUBVYXrfDcbXe28Iy1E5a5SFHyCPq5M='****** \n")
          
              
          
            flag = False        
        elif in2 >= 20 and in2 <= 29:
            query_sid = f'Select encrypt from encrypt_data1 Where Iage = {3}'
            y=c.execute(query_sid)
            l=[]
            for row in y:
                l.append(str(row))
              
            for i in l:
                en = str.encode(i)[2:len(str.encode(i))-3]
                decrypted_encrypted = f.decrypt(en)
                res = tuple(map(int, decrypted_encrypted.decode()[1:len(decrypted_encrypted.decode())-1].split(', '))) 
                if res[2]==in2:
                    print("your Query Result is:")
                    
                    t = PrettyTable(['sid' ,'nid' , 'age', 'grade'])
                    t.add_row([res[0],res[1], res[2],res[3]])
                    print(t)
                    print("\n")
                    print("More details:\n")
                    print("===>>>Recovered records from BigData:")
                    print(l)
                    print()
                    print("===>>>encrypted data is:"+str(en))
                    print()
                    print("*****The generated key is==>>> b'CiWj2kb9hg3SXUBVYXrfDcbXe28Iy1E5a5SFHyCPq5M='****** \n")
        
            flag = False
        elif in2 >= 30 and in2 <= 39:
            query_sid = f'Select encrypt from encrypt_data1 Where Iage = {4}'
            y=c.execute(query_sid)
            l=[]
            for row in y:
                l.append(str(row))
              
            for i in l:
                en = str.encode(i)[2:len(str.encode(i))-3]
                decrypted_encrypted = f.decrypt(en)
                res = tuple(map(int, decrypted_encrypted.decode()[1:len(decrypted_encrypted.decode())-1].split(', '))) 
                if res[2]==in2:
                    print("your Query Result is:")
                    
                    t = PrettyTable(['sid' ,'nid' , 'age', 'grade'])
                    t.add_row([res[0],res[1], res[2],res[3]])
                    print(t)
                    print("\n")
                    print("More details:\n")
                    print("===>>>Recovered records from BigData:")
                    print(l)
                    print()
                    print("===>>>encrypted data is:"+str(en))
                    print()
                    print("*****The generated key is==>>> b'CiWj2kb9hg3SXUBVYXrfDcbXe28Iy1E5a5SFHyCPq5M='****** \n")
             
       
            flag = False        
        else :
            print("contact IGZ 09086493523")
            
  ###################################################################################          
    elif inp == 4:
        
        in2 = int(input("enter IGrade: "))
        if in2 > 0 and in2 <= 4 :
            query_sid = f'Select encrypt from encrypt_data1 Where Igrade = {1}'
            y=c.execute(query_sid)
            l=[]
            for row in y:
                l.append(str(row))
              
            for i in l:
                en = str.encode(i)[2:len(str.encode(i))-3]
                decrypted_encrypted = f.decrypt(en)
                res = tuple(map(int, decrypted_encrypted.decode()[1:len(decrypted_encrypted.decode())-1].split(', '))) 
                if res[3]==in2:
                    print("your Query Result is:")
                    
                    t = PrettyTable(['sid' ,'nid' , 'age', 'grade'])
                    t.add_row([res[0],res[1], res[2],res[3]])
                    print(t)
                    print("\n")
                    print("More details:\n")
                    print("===>>>Recovered records from BigData:")
                    print(l)
                    print()
                    print("===>>>encrypted data is:"+str(en))
                    print()
                    print("*****The generated key is==>>> b'CiWj2kb9hg3SXUBVYXrfDcbXe28Iy1E5a5SFHyCPq5M='****** \n")
        
                
               
            flag = False
           
        elif in2 >= 5 and in2 <= 9:
            query_sid = f'Select encrypt from encrypt_data1 Where Igrade = {2}'
            y=c.execute(query_sid)
            l=[]
            for row in y:
                l.append(str(row))
                
            for i in l:
                en = str.encode(i)[2:len(str.encode(i))-3]
                decrypted_encrypted = f.decrypt(en)
                res = tuple(map(int, decrypted_encrypted.decode()[1:len(decrypted_encrypted.decode())-1].split(', '))) 
                if res[3]==in2:
                    print("your Query Result is:")
                    
                    t = PrettyTable(['sid' ,'nid' , 'age', 'grade'])
                    t.add_row([res[0],res[1], res[2],res[3]])
                    print(t)
                    print("\n")
                    print("More details:\n")
                    print("===>>>Recovered records from BigData:")
                    print(l)
                    print()
                    print("===>>>encrypted data is:"+str(en))
                    print()
                    print("*****The generated key is==>>> b'CiWj2kb9hg3SXUBVYXrfDcbXe28Iy1E5a5SFHyCPq5M='****** \n")
        
              
          
            flag = False        
        elif in2 >= 10 and in2 <= 14:
            query_sid = f'Select encrypt from encrypt_data1 Where Igrade = {3}'
            y=c.execute(query_sid)
            l=[]
            for row in y:
                l.append(str(row))
              
            for i in l:
                en = str.encode(i)[2:len(str.encode(i))-3]
                decrypted_encrypted = f.decrypt(en)
                res = tuple(map(int, decrypted_encrypted.decode()[1:len(decrypted_encrypted.decode())-1].split(', '))) 
                if res[3]==in2:
                    print("your Query Result is:")
                    
                    t = PrettyTable(['sid' ,'nid' , 'age', 'grade'])
                    t.add_row([res[0],res[1], res[2],res[3]])
                    print(t)
                    print("\n")
                    print("More details:\n")
                    print("===>>>Recovered records from BigData:")
                    print(l)
                    print()
                    print("===>>>encrypted data is:"+str(en))
                    print()
                    print("*****The generated key is==>>> b'CiWj2kb9hg3SXUBVYXrfDcbXe28Iy1E5a5SFHyCPq5M='****** \n")
            
            flag = False
        elif in2 >= 15 and in2 <= 20:
            query_sid = f'Select encrypt from encrypt_data1 Where Igrade = {4}'
            y=c.execute(query_sid)
            l=[]
            for row in y:
                l.append(str(row))
              
            for i in l:
                en = str.encode(i)[2:len(str.encode(i))-3]
                decrypted_encrypted = f.decrypt(en)
                res = tuple(map(int, decrypted_encrypted.decode()[1:len(decrypted_encrypted.decode())-1].split(', '))) 
                if res[3]==in2:
                    print("your Query Result is:")
                    
                    t = PrettyTable(['sid' ,'nid' , 'age', 'grade'])
                    t.add_row([res[0],res[1], res[2],res[3]])
                    print(t)
                    print("\n")
                    print("More details:\n")
                    print("===>>>Recovered records from BigData:")
                    print(l)
                    print()
                    print("===>>>encrypted data is:"+str(en))
                    print()
                    print("*****The generated key is==>>> b'CiWj2kb9hg3SXUBVYXrfDcbXe28Iy1E5a5SFHyCPq5M='****** \n")
       
            flag = False        
        else :
            print("contact IGZ 09086493523")
    else :
           print("Not match any option")
# Out:
# *********************
# welcom to SarvSearch
# # menu
# 1 : search StudentID
# 2 : search NationalID
# 3 : search Age
# 4 : search Grade
# *********************
# please Select a number from 1 to 4 :2
# enter Inid: 150
# your Query Result is:
# +-----+-----+-----+-------+
# | sid | nid | age | grade |
# +-----+-----+-----+-------+
# |  15 | 150 |  21 |   18  |
# +-----+-----+-----+-------+
#
#
# More details:
#
# ===>>>Recovered records from BigData:
# ["('gAAAAABesLVlHD2WTlmz0UKs7TGJ2UMDDVla6ShCz7xaNse42YVPFKhq96Jau0psKrDvxTsN3dKYgVyGAubCzIzz24XSwyS77RX35TX6RMRUtA4zELme8lU=',)", "('gAAAAABesLV6Zia5TvmWG4CbT-F79ZHcRkdrZBTCMbVabGz1DGHlaQ0IgOYYpn4gzRTAjjs-s-zCjVxwTt7Noam4pXpNHdrSkf5gt6lQCbOYjPu8N8A_oBg=',)"]
#
# ===>>>encrypted data is:b'gAAAAABesLVlHD2WTlmz0UKs7TGJ2UMDDVla6ShCz7xaNse42YVPFKhq96Jau0psKrDvxTsN3dKYgVyGAubCzIzz24XSwyS77RX35TX6RMRUtA4zELme8lU='
#
# *****The generated key is==>>> b'CiWj2kb9hg3SXUBVYXrfDcbXe28Iy1E5a5SFHyCPq5M='******

# %%
#b'CiWj2kb9hg3SXUBVYXrfDcbXe28Iy1E5a5SFHyCPq5M=' ===>>>>>> Key
# Out:
# b'CiWj2kb9hg3SXUBVYXrfDcbXe28Iy1E5a5SFHyCPq5M='

# %%
#b'gAAAAABesLSYpDoDwno9Re54MStZLjy6sJo21qcKRJTPoFZcyDsNARR255oZOY_8hLX9xSfn2gUHjEWb_GFXByWEHGzdAZyZlw=='
#b'gAAAAABesLVlHD2WTlmz0UKs7TGJ2UMDDVla6ShCz7xaNse42YVPFKhq96Jau0psKrDvxTsN3dKYgVyGAubCzIzz24XSwyS77RX35TX6RMRUtA4zELme8lU='
#b'gAAAAABesLV6Zia5TvmWG4CbT-F79ZHcRkdrZBTCMbVabGz1DGHlaQ0IgOYYpn4gzRTAjjs-s-zCjVxwTt7Noam4pXpNHdrSkf5gt6lQCbOYjPu8N8A_oBg='
#b'gAAAAABesLWSMCENc53mNANHX8zjAvka94yMwlnL829T6-hPjcUQYxLi7VsPZu2eHA70Ei7dn-345BPEv7GX2WJnv1aD2n0rJhHdMqh6pFS9tmMHz2Apzw8='
